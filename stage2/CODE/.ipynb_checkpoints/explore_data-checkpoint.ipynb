# %% [markdown]
# # Explore movie data scraped from IMDB and Rotten Tomatoes

# %%
import pandas as pd
import csv
import numpy as np

# %%
# imdb movies
table_a = pd.read_csv("../DATA/table_a.csv")
# rotten tomatoes movies
table_b = pd.read_csv("../DATA/table_b.csv")

# %% [markdown]
# ## Viewing IMDB Movies as a table
# ### NOTE: Change n to view more movies

# %%
n = 5
table_a.head(n)
# Out:
#                            movie_name  movie_year           director  runtime  \
# 0                        Pulp Fiction        1994  Quentin Tarantino  154 min
# 1            The Amazing Spider-Man 2        2014          Marc Webb  142 min
# 2            The Shawshank Redemption        1994     Frank Darabont  142 min
# 3  Star Wars: Episode IV - A New Hope        1977       George Lucas  121 min
# 4                  Back to the Future        1985    Robert Zemeckis  116 min
#
#                         genre  rating  \
# 0                Crime, Drama     8.9
# 1   Action, Adventure, Sci-Fi     6.6
# 2                       Drama     9.3
# 3  Action, Adventure, Fantasy     8.6
# 4   Adventure, Comedy, Sci-Fi     8.5
#
#                                          description certificate
# 0  The lives of two mob hitmen, a boxer, a gangst...           R
# 1  When New York is put under siege by Oscorp, it...       PG-13
# 2  Two imprisoned men bond over a number of years...           R
# ...

# %% [markdown]
# ## Viewing Rotten Tomatoes Movies as a table
# ### NOTE: Change n to view more movies

# %%
n = 5
table_b.head(n)
# Out:
#                  movie_name  movie_year              director      runtime  \
# 0             All About Eve        1950  Joseph L. Mankiewicz  138 minutes
# 1          Sunset Boulevard        1950          Billy Wilder  111 minutes
# 2  A Streetcar Named Desire        1951            Elia Kazan  122 minutes
# 3                  Rashômon        1951        Akira Kurosawa   83 minutes
# 4      Strangers on a Train        1951      Alfred Hitchcock  101 minutes
#
#                                                genre rating  \
# 0                                     Classics,Drama   100%
# 1                                     Classics,Drama    98%
# 2                                     Classics,Drama    98%
# 3  Art House & International,Classics,Drama,Myste...    98%
# 4                                 Mystery & Suspense    98%
#
#                                          description     certificate
# 0  Based on the story The Wisdom of Eve by Mary O...              PG
# ...
